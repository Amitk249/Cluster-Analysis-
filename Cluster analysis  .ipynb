# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np  
import matplotlib as plt 
import seaborn as sn

# %%
# %matplotlib inline

# %%
df = pd.read_csv("D:/laptopdata.csv")

# %%
df
# Out:
#       Sr.NO Company            TypeName Inches  \
# 0         1   Apple           Ultrabook   13.3
# 1         2   Apple           Ultrabook   13.3
# 2         3      HP            Notebook   15.6
# 3         4   Apple           Ultrabook   15.4
# 4         5   Apple           Ultrabook   13.3
# ...     ...     ...                 ...    ...
# 1268   1298  Lenovo  2 in 1 Convertible     14
# 1269   1299  Lenovo  2 in 1 Convertible   13.3
# 1270   1300  Lenovo            Notebook     14
# 1271   1301      HP            Notebook   15.6
# 1272   1302    Asus            Notebook   15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...                                          ...
# ...

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns',None)

# %%
df
# Out:
#       Sr.NO    Company            TypeName Inches  \
# 0         1      Apple           Ultrabook   13.3
# 1         2      Apple           Ultrabook   13.3
# 2         3         HP            Notebook   15.6
# 3         4      Apple           Ultrabook   15.4
# 4         5      Apple           Ultrabook   13.3
# 5         6       Acer            Notebook   15.6
# 6         7      Apple           Ultrabook   15.4
# 7         8      Apple           Ultrabook   13.3
# 8         9       Asus           Ultrabook     14
# 9        10       Acer           Ultrabook     14
# 10       11         HP            Notebook   15.6
# 11       12         HP            Notebook   15.6
# 12       13      Apple           Ultrabook   15.4
# 13       14       Dell            Notebook   15.6
# 14       15      Apple           Ultrabook     12
# 15       16      Apple           Ultrabook   13.3
# 16       17       Dell            Notebook   15.6
# 17       18      Apple           Ultrabook   15.4
# ...

# %%
sn.lmplot(data = df ,x = 'Sr.NO',y = 'Price', fit_reg = False ,aspect = 3, height = 5)

# %%
pip install scikit-learn
# Out:
# ...
#
# ...

# %%
numeric = df.select_dtypes(include=['number'])

# %%
from sklearn.cluster import KMeans

# %%
cluster = KMeans(3)
cluster.fit(numeric)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
numeric['clusterid'] = cluster.labels_

# %%
numeric[0:5]
# Out:
#    Sr.NO        Price  clusterid
# 0      1   71378.6832          2
# 1      2   47895.5232          0
# 2      3   30636.0000          0
# 3      4  135195.3360          1
# 4      5   96095.8080          2

# %%
markers = ['+', '^', '.']

sn.lmplot(data = numeric , x = 'Sr.NO', y = 'Price', hue = 'clusterid',fit_reg = False , markers = markers , aspect = 2 , height = 5)

# %% [markdown]
# # KMEANS clustering Using Normalization method

# %%
from sklearn.preprocessing import StandardScaler

# %%
scalar = StandardScaler()
scaled_data  = scalar.fit_transform(numeric[['Sr.NO','Price']])

# %%
scaled_data[0:5]
# Out:
# array([[-1.73175344,  0.30609883],
#        [-1.72909611, -0.32317983],
#        [-1.72643879, -0.78568359],
#        [-1.72378146,  2.01619483],
#        [-1.72112414,  0.96844407]])

# %%
from sklearn.cluster import KMeans

# %%
clusters_New = KMeans(3, random_state = 45)
clusters_New.fit(scaled_data)
numeric['clusterid_new'] = clusters_New.labels_
# Out:
# D:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# D:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=5.
#   warnings.warn(

# %%
markers = ['*','^','.']
sn.lmplot(data = numeric , x = 'Sr.NO', y = 'Price', hue = 'clusterid_new',fit_reg = False , markers = markers , aspect = 2 , height = 5)
